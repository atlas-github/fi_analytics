# %% [markdown]
# <a href="https://colab.research.google.com/github/atlas-github/fi_analytics/blob/master/Chapter_6_Retrieve_tweets_using_Twitter_APIs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Get Tweet timelines

# %% [markdown]
# It’s already in Python, so we’ll just need to copy and paste it into a Notebook. Let’s use Google Colab for this demonstration.

# %%
import requests

url = "https://api.twitter.com/1.1/statuses/user_timeline.json?screen_name=MyMaybank&count=200"

payload = {}
headers = {
  'Authorization': 'OAuth oauth_consumer_key="NLcV8rT32sgnc8TW0J0Jar4t2",oauth_token="525142558-izI3eJOuu5WZh0tX03uqHwyo9Ff54ZFeBmOAAFI8",oauth_signature_method="HMAC-SHA1",oauth_timestamp="1593697409",oauth_nonce="SayH9Om1OnT",oauth_version="1.0",oauth_signature="o7TWiScz7zx%2BA71e2SWlrjb0R8A%3D"',
  'Cookie': 'personalization_id="v1_ozf0qxItQhTU85AdGjOntA=="; guest_id=v1%3A158601607647811491; lang=en'
}

response = requests.request("GET", url, headers=headers, data = payload)

print(response.text.encode('utf8'))
# Out:
# b'[{"created_at":"Thu Jul 02 13:37:14 +0000 2020","id":1278684156549988352,"id_str":"1278684156549988352","text":"@juliajasminee @BankMegaID Salam sejahtera. Segala kesulitan amat dikesali. Tidak perlu bimbang, kami akan bantu an\\u2026 https:\\/\\/t.co\\/xSyRtSV432","truncated":true,"entities":{"hashtags":[],"symbols":[],"user_mentions":[{"screen_name":"juliajasminee","name":"J Jasmine","id":103265914,"id_str":"103265914","indices":[0,14]},{"screen_name":"BankMegaID","name":"PT Bank Mega Tbk.","id":2935822387,"id_str":"2935822387","indices":[15,26]}],"urls":[{"url":"https:\\/\\/t.co\\/xSyRtSV432","expanded_url":"https:\\/\\/twitter.com\\/i\\/web\\/status\\/1278684156549988352","display_url":"twitter.com\\/i\\/web\\/status\\/1\\u2026","indices":[117,140]}]},"source":"\\u003ca href=\\"http:\\/\\/www.namemo.com\\" rel=\\"nofollow\\"\\u003eZanroo_Analytic\\u003c\\/a\\u003e","in_reply_to_status_id":1278138976725958656,"in_reply_to_status_id_str":"1278138976725958656","in_reply_to_user_id
# ...

# %% [markdown]
# Notice the code output is not yet in a table. I’d like to modify the last line of the code by inserting the following script:

# %%
import pandas as pd
example = response.json()
df = pd.DataFrame(example)
df
# Out:
#                          created_at  ...  possibly_sensitive
# 0    Thu Jul 02 13:37:14 +0000 2020  ...                 NaN
# 1    Thu Jul 02 13:06:39 +0000 2020  ...                 NaN
# 2    Thu Jul 02 13:06:24 +0000 2020  ...                 NaN
# 3    Thu Jul 02 13:06:13 +0000 2020  ...                 NaN
# 4    Thu Jul 02 12:52:38 +0000 2020  ...                 NaN
# ..                              ...  ...                 ...
# 195  Mon Jun 29 11:23:19 +0000 2020  ...                 NaN
# 196  Mon Jun 29 11:08:55 +0000 2020  ...                 NaN
# 197  Mon Jun 29 10:44:54 +0000 2020  ...                 NaN
# 198  Mon Jun 29 09:24:01 +0000 2020  ...                 NaN
# 199  Mon Jun 29 09:00:11 +0000 2020  ...               False
#
# [200 rows x 24 columns]

# %% [markdown]
# To download the table onto your machine for further analysis, add the following snippet:

# %%
df.to_csv("tweets.csv")
from google.colab import files
files.download("tweets.csv")
